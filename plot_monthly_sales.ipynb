# %%
import main
import matplotlib.pyplot as plt
df3=main.monthly_sales
plt.plot(df3.mod_dt,df3.Weekly_Sales/10**6)
plt.locator_params(axis='x', nbins=1)
plt.xlabel('Months')
plt.ylabel('Sales in million units')
plt.xticks(rotation=90)
plt.show()
