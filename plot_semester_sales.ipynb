# %%
import main
import matplotlib.pyplot as plt
df3=main.sem_sales
import matplotlib.pyplot as plt
plt.plot(df3.semester,df3.Weekly_Sales/10**6)
plt.locator_params(axis='x', nbins=1)
plt.xlabel('Semester')
plt.ylabel('Sales in million units')
plt.xticks(rotation=90)
fig=plt.figure(figsize=(350, 3))
fig.show()
